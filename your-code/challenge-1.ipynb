# %% [markdown]
# # Challenge 1 - Tic Tac Toe
#
# In this lab you will perform deep learning analysis on a dataset of playing [Tic Tac Toe](https://en.wikipedia.org/wiki/Tic-tac-toe).
#
# There are 9 grids in Tic Tac Toe that are coded as the following picture shows:
#
# ![Tic Tac Toe Grids](https://github.com/ironhack-labs/lab-neural-networks/blob/master/your-code/tttboard.jpg?raw=1)
#
# In the first 9 columns of the dataset you can find which marks (`x` or `o`) exist in the grids. If there is no mark in a certain grid, it is labeled as `b`. The last column is `class` which tells you whether Player X (who always moves first in Tic Tac Toe) wins in this configuration. Note that when `class` has the value `False`, it means either Player O wins the game or it ends up as a draw.

# %% [markdown]
# Follow the steps suggested below to conduct a neural network analysis using Tensorflow and Keras. You will build a deep learning model to predict whether Player X wins the game or not.
#
# ## Step 1: Data Engineering
#
# This dataset is almost in the ready-to-use state so you do not need to worry about missing values and so on. Still, some simple data engineering is needed.
#
# 1. Read `tic-tac-toe.csv` into a dataframe.
# 1. Inspect the dataset. Determine if the dataset is reliable by eyeballing the data.
# 1. Convert the categorical values to numeric in all columns.
# 1. Separate the inputs and output.
# 1. Normalize the input data.

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# 2. Leer el dataset
# Aquí se asume que tienes el archivo en CSV. Si el archivo original es .data, asegúrate de convertirlo o renombrar.
df = pd.read_csv("/tic-tac-toe.csv")

print("Primeras filas:")
print(df.head())
print("\nInformación general:")
print(df.info())
print("\nValores únicos por columna:")
for col in df.columns:
    print(col, "->", df[col].unique())

print("\nConteo de la variable objetivo:")
print(df['class'].value_counts())  # Nota: en este dataset la columna “class” es el target (positive/negative) :contentReference[oaicite:2]{index=2}

# 4. Convertir valores categóricos a numéricos en todas las columnas
encoder = LabelEncoder()
for col in df.columns:
    df[col] = encoder.fit_transform(df[col])

print("\nDespués de codificar:")
print(df.head())

# 5. Separar variables de entrada (X) y salida (y)
X = df.drop('class', axis=1)
y = df['class']

print("\nDimensiones de X:", X.shape)
print("Dimensión de y:", y.shape)

# 6. Normalizar los datos de entrada
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Convertir de nuevo a DataFrame para mantener nombres de columnas (opcional)
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

print("\nPrimeras filas de los datos escalados:")
print(X_scaled.head())
# Out:
# Primeras filas:
#   TL TM TR ML MM MR BL BM BR  class
# 0  x  x  x  x  o  o  x  o  o   True
# 1  x  x  x  x  o  o  o  x  o   True
# 2  x  x  x  x  o  o  o  o  x   True
# 3  x  x  x  x  o  o  o  b  b   True
# 4  x  x  x  x  o  o  b  o  b   True
#
# Información general:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 958 entries, 0 to 957
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TL      958 non-null    object
#  1   TM      958 non-null    object
#  2   TR      958 non-null    object
#  3   ML      958 non-null    object
#  4   MM      958 non-null    object
#  5   MR      958 non-null    object
#  6   BL      958 non-null    object
#  7   BM      958 non-null    object
#  8   BR      958 non-null    object
#  9   class   958 non-null    bool
# dtypes: bool(1), object(9)
# memory usage: 68.4+ KB
# None
#
# Valores únicos por columna:
# TL -> ['x' 'o' 'b']
# TM -> ['x' 'o' 'b']
# TR -> ['x' 'o' 'b']
# ...

# %%
concrete_data = pd.read_csv('/tic-tac-toe.csv')
concrete_data.head()
# Out:
#   TL TM TR ML MM MR BL BM BR  class
# 0  x  x  x  x  o  o  x  o  o   True
# 1  x  x  x  x  o  o  o  x  o   True
# 2  x  x  x  x  o  o  o  o  x   True
# 3  x  x  x  x  o  o  o  b  b   True
# 4  x  x  x  x  o  o  b  o  b   True

# %%
concrete_data.shape
# Out:
# (958, 10)

# %%
concrete_data.describe()
# Out:
#          TL   TM   TR   ML   MM   MR   BL   BM   BR class
# count   958  958  958  958  958  958  958  958  958   958
# unique    3    3    3    3    3    3    3    3    3     2
# top       x    x    x    x    x    x    x    x    x  True
# freq    418  378  418  378  458  378  418  378  418   626

# %%
concrete_data.isnull().sum()
# Out:
# TL       0
# TM       0
# TR       0
# ML       0
# MM       0
# MR       0
# BL       0
# BM       0
# BR       0
# class    0
# dtype: int64

# %%
concrete_data_columns = concrete_data.columns

predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'BR']] # all columns except Strength
target = concrete_data['BR'] # BR column

# %%
predictors.head()
# Out:
#   TL TM TR ML MM MR BL BM  class
# 0  x  x  x  x  o  o  x  o   True
# 1  x  x  x  x  o  o  o  x   True
# 2  x  x  x  x  o  o  o  o   True
# 3  x  x  x  x  o  o  o  b   True
# 4  x  x  x  x  o  o  b  o   True

# %%
target.head()
# Out:
# 0    o
# 1    o
# 2    x
# 3    b
# 4    b
# Name: BR, dtype: object

# %%
encoder = LabelEncoder()
for col in df.columns:
    df[col] = encoder.fit_transform(df[col])
X = df.drop('class', axis=1)
y = df['class']

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

X_scaled = pd.DataFrame(X_scaled, columns=X.columns)
print("\nPrimeras filas de los datos escalados:")
print(X_scaled.head())
# Out:
# Primeras filas de los datos escalados:
#     TL   TM   TR   ML   MM   MR   BL   BM   BR
# 0  1.0  1.0  1.0  1.0  0.5  0.5  1.0  0.5  0.5
# 1  1.0  1.0  1.0  1.0  0.5  0.5  0.5  1.0  0.5
# 2  1.0  1.0  1.0  1.0  0.5  0.5  0.5  0.5  1.0
# 3  1.0  1.0  1.0  1.0  0.5  0.5  0.5  0.0  0.0
# 4  1.0  1.0  1.0  1.0  0.5  0.5  0.0  0.5  0.0

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3025399014.py in <cell line: 0>()
# ----> 1 predictors_norm = (predictors - predictors.mean()) / predictors.std()
#       2 predictors_norm.head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11691         **kwargs,
#   11692     ):
# > 11693         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694         if isinstance(result, Series):
#   11695             result = result.__finalize__(self, method="mean")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
#   12421             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
# ...

# %% [markdown]
# ## Step 2: Build Neural Network
#
# To build the neural network, you can refer to your own codes you wrote while following the [Deep Learning with Python, TensorFlow, and Keras tutorial](https://www.youtube.com/watch?v=wQ8BIBpya2k) in the lesson. It's pretty similar to what you will be doing in this lab.
#
# 1. Split the training and test data.
# 1. Create a `Sequential` model.
# 1. Add several layers to your model. Make sure you use ReLU as the activation function for the middle layers. Use Softmax for the output layer because each output has a single lable and all the label probabilities add up to 1.
# 1. Compile the model using `adam` as the optimizer and `sparse_categorical_crossentropy` as the loss function. For metrics, use `accuracy` for now.
# 1. Fit the training data.
# 1. Evaluate your neural network model with the test data.
# 1. Save your model as `tic-tac-toe.model`.

# %%
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(32, input_dim=9, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))

    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
    # build the model
model = regression_model()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

# %%
model.fit(X_train, y_train, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 24/24 - 1s - 41ms/step - loss: 0.2524
# Epoch 2/100
# 24/24 - 0s - 3ms/step - loss: 0.2117
# Epoch 3/100
# 24/24 - 0s - 2ms/step - loss: 0.2009
# Epoch 4/100
# 24/24 - 0s - 2ms/step - loss: 0.1935
# Epoch 5/100
# 24/24 - 0s - 2ms/step - loss: 0.1882
# Epoch 6/100
# 24/24 - 0s - 2ms/step - loss: 0.1843
# Epoch 7/100
# 24/24 - 0s - 2ms/step - loss: 0.1797
# Epoch 8/100
# 24/24 - 0s - 3ms/step - loss: 0.1742
# Epoch 9/100
# 24/24 - 0s - 3ms/step - loss: 0.1710
# Epoch 10/100
# 24/24 - 0s - 2ms/step - loss: 0.1693
# Epoch 11/100
# 24/24 - 0s - 3ms/step - loss: 0.1648
# Epoch 12/100
# 24/24 - 0s - 2ms/step - loss: 0.1605
# Epoch 13/100
# 24/24 - 0s - 2ms/step - loss: 0.1561
# Epoch 14/100
# 24/24 - 0s - 2ms/step - loss: 0.1532
# Epoch 15/100
# 24/24 - 0s - 2ms/step - loss: 0.1496
# Epoch 16/100
# 24/24 - 0s - 2ms/step - loss: 0.1482
# Epoch 17/100
# 24/24 - 0s - 2ms/step - loss: 0.1475
# Epoch 18/100
# 24/24 - 0s - 2ms/step - loss: 0.1377
# Epoch 19/100
# ...

# %%
# your code here
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split

# 2. Dividir datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

# 3. Crear modelo secuencial
model = Sequentimodel.add(Dense(32, input_dim=9, activation='relu'))al()

# 4. Agregar capas ocultas (ReLU) y capa de salida (Softmax)
model.add(Dense(32, input_dim=9, activation='relu'))  # Capa oculta 1
model.add(Dense(16, activation='relu'))               # Capa oculta 2
model.add(Dense(8, activation='relu'))                # Capa oculta 3
model.add(Dense(2, activation='softmax'))            # Capa de salida para 2 clases

# 5. Compilar modelo
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# 6. Entrenar modelo
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=16,
    validation_split=0.2,
    verbose=1
)


loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"\nTest Accuracy: {accuracy:.4f}")
print(f"Test Loss: {loss:.4f}")


model.save("tic-tac-toe.keras")
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.6912 - loss: 0.6566 - val_accuracy: 0.6364 - val_loss: 0.6468
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6689 - loss: 0.6302 - val_accuracy: 0.6364 - val_loss: 0.6462
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6583 - loss: 0.6241 - val_accuracy: 0.6364 - val_loss: 0.6438
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6358 - loss: 0.6300 - val_accuracy: 0.6364 - val_loss: 0.6433
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6289 - loss: 0.6232 - val_accuracy: 0.6364 - val_loss: 0.6415
# Epoch 6/50
# ...

# %% [markdown]
# ## Step 3: Make Predictions
#
# Now load your saved model and use it to make predictions on a few random rows in the test dataset. Check if the predictions are correct.

# %%
# your code here
import numpy as np
from tensorflow.keras.models import load_model

# 1. Cargar el modelo previamente guardado
model = load_model("tic-tac-toe.keras")
print("Modelo cargado correctamente.")

# 2. Seleccionar algunas filas aleatorias del set de prueba
num_samples = 5  # cantidad de predicciones que queremos revisar
random_indices = np.random.choice(X_test.shape[0], num_samples, replace=False)
X_sample = X_test.iloc[random_indices]
y_true = y_test.iloc[random_indices]

# 3. Hacer predicciones
pred_probs = model.predict(X_sample)          # Probabilidades de cada clase
pred_classes = np.argmax(pred_probs, axis=1) # Convertir a la clase con mayor probabilidad

# 4. Mostrar resultados
for i in range(num_samples):
    print(f"\nFila #{i+1}:")
    print("Datos de entrada:", X_sample.iloc[i].values)
    print("Etiqueta real:", y_true.iloc[i])
    print("Predicción del modelo:", pred_classes[i])
# Out:
# Modelo cargado correctamente.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
#
# Fila #1:
# Datos de entrada: [1.  1.  0.  1.  0.5 0.  1.  0.5 0.5]
# Etiqueta real: 1
# Predicción del modelo: 1
#
# Fila #2:
# Datos de entrada: [0.5 0.5 0.  1.  1.  1.  0.  1.  0.5]
# Etiqueta real: 1
# Predicción del modelo: 1
#
# Fila #3:
# Datos de entrada: [0.  0.5 1.  0.  0.5 1.  1.  0.5 0. ]
# Etiqueta real: 0
# Predicción del modelo: 0
#
# Fila #4:
# Datos de entrada: [0.5 1.  1.  0.  1.  0.  1.  0.5 0.5]
# Etiqueta real: 1
# Predicción del modelo: 1
#
# Fila #5:
# Datos de entrada: [1.  1.  0.5 0.5 0.5 0.  0.5 1.  1. ]
# Etiqueta real: 0
# Predicción del modelo: 1

# %% [markdown]
# ## Step 4: Improve Your Model
#
# Did your model achieve low loss (<0.1) and high accuracy (>0.95)? If not, try to improve your model.
#
# But how? There are so many things you can play with in Tensorflow and in the next challenge you'll learn about these things. But in this challenge, let's just do a few things to see if they will help.
#
# * Add more layers to your model. If the data are complex you need more layers. But don't use more layers than you need. If adding more layers does not improve the model performance you don't need additional layers.
# * Adjust the learning rate when you compile the model. This means you will create a custom `tf.keras.optimizers.Adam` instance where you specify the learning rate you want. Then pass the instance to `model.compile` as the optimizer.
#     * `tf.keras.optimizers.Adam` [reference](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam).
#     * Don't worry if you don't understand what the learning rate does. You'll learn about it in the next challenge.
# * Adjust the number of epochs when you fit the training data to the model. Your model performance continues to improve as you train more epochs. But eventually it will reach the ceiling and the performance will stay the same.

# %%
# your code here

from tensorflow.keras.optimizers import Adam

# 1. Crear un nuevo modelo secuencial con más capas
improved_model = Sequential()

# Capas ocultas adicionales para mejorar aprendizaje
improved_model.add(Dense(64, input_dim=9, activation='relu'))  # Capa oculta 1
improved_model.add(Dense(32, activation='relu'))               # Capa oculta 2
improved_model.add(Dense(16, activation='relu'))               # Capa oculta 3
improved_model.add(Dense(8, activation='relu'))                # Capa oculta 4
improved_model.add(Dense(2, activation='softmax'))             # Capa de salida

# 2. Ajustar el learning rate creando un optimizador Adam personalizado
optimizer = Adam(learning_rate=0.005)  # valor por defecto es 0.001

# 3. Compilar el modelo
improved_model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# 4. Entrenar el modelo con más epochs
history = improved_model.fit(
    X_train, y_train,
    epochs=100,        # más epochs para mejorar el aprendizaje
    batch_size=16,
    validation_split=0.2,
    verbose=1
)

# 5. Evaluar el modelo mejorado
loss, accuracy = improved_model.evaluate(X_test, y_test, verbose=0)
print(f"\nTest Accuracy (mejorado): {accuracy:.4f}")
print(f"Test Loss (mejorado): {loss:.4f}")

# 6. Guardar el modelo mejorado
improved_model.save("tic-tac-toe-improved.keras")
print("\nModelo mejorado guardado como 'tic-tac-toe-improved.model'")
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.6091 - loss: 0.6458 - val_accuracy: 0.6364 - val_loss: 0.6270
# Epoch 2/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6705 - loss: 0.5947 - val_accuracy: 0.6429 - val_loss: 0.6123
# Epoch 3/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6512 - loss: 0.5841 - val_accuracy: 0.6558 - val_loss: 0.6755
# Epoch 4/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7118 - loss: 0.5650 - val_accuracy: 0.7143 - val_loss: 0.5731
# Epoch 5/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7560 - loss: 0.4923 - val_accuracy: 0.7597 - val_loss: 0.5214
# ...

# %% [markdown]
# **Which approach(es) did you find helpful to improve your model performance?**

# %%
# your answer here
